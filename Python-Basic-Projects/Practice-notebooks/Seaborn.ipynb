# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing dataset directly from Seaborn Github

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Distribution Plot

# %% [markdown]
# # 1. Histogram

# %%
sns.histplot(df["total_bill"])
plt.show()

# %%
# Printing skewness of the distribution.
sns.histplot(df['total_bill'], kde=True)
plt.show()

# %%
sns.histplot(df['tip'])
plt.show()

# %%
sns.histplot(df['tip'], kde=True)
plt.show()

# %% [markdown]
# # 2. Joinplot

# %%
sns.jointplot(x='total_bill', y='tip',data= df, kind='scatter')
plt.show()

# %%
sns.jointplot(x='total_bill', y='tip',data= df, kind='hex')
plt.show()

# %%
sns.jointplot(x='total_bill', y='tip',data= df, kind='hist')
plt.show()

# %%
sns.jointplot(x='total_bill', y='tip',data= df, kind='kde')
plt.show()

# %%
sns.jointplot(x='total_bill', y='tip',data= df, kind='reg')
plt.show()

# %% [markdown]
# # 3. PairPlot

# %%
sns.pairplot(df)
plt.show()

# %%
sns.pairplot(df, hue='sex')
plt.show()

# %%
sns.pairplot(df, hue='size', palette='rainbow')
plt.show()

# %% [markdown]
# # Count Plot

# %%
sns.countplot(x = df['sex'])
plt.show()

# %%
sns.countplot(x =df['sex'],hue=df['smoker'])
plt.show()

# %% [markdown]
# # Bar Plot

# %%
sns.barplot(x= df['sex'], y=df['total_bill'])
plt.show()

# %%
import numpy as np
sns.barplot(x= df['sex'], y=df['total_bill'], estimator=np.sum)
plt.show()

# %%
sns.barplot(x= df['sex'], y=df['tip'], estimator=np.sum)
plt.show()

# %%
sns.barplot(x= df['sex'], y=df['tip'], hue=df['day'], estimator=np.sum)
plt.show()

# %%
sns.barplot(x= df['sex'], y=df['tip'], hue=df['smoker'], estimator=np.sum)
plt.show()

# %%
sns.barplot(x= df['sex'], y=df['tip'], hue=df['time'], estimator=np.sum)
plt.show()

# %% [markdown]
# # Box Plot

# %%
sns.boxplot(x= df['tip'], y= df['day'])
plt.show()

# %%
sns.boxplot(x= df['tip'], y= df['day'], hue=df['sex'])
plt.show()

# %% [markdown]
# # Strip Plot

# %%
sns.stripplot(y= df['total_bill'], x=df['day'])
plt.show()

# %%
sns.stripplot(y= df['total_bill'], x=df['day'], hue=df['sex'])
plt.show()

# %%
sns.stripplot(y= df['tip'], x=df['day'], hue=df['sex'])
plt.show()

# %%
sns.stripplot(y= df['tip'], x=df['sex'])
plt.show()

# %%
sns.stripplot(y= df['tip'], x=df['sex'], hue=df['day'])
plt.show()

# %% [markdown]
# # Violin Plot

# %%
sns.violinplot(x=df['sex'], y=df['total_bill'])
plt.show()

# %%
sns.violinplot(x= df['day'], y= df['total_bill'])
plt.show()

# %% [markdown]
# # Swarm Plot

# %%
sns.swarmplot(x= df['day'], y=df['total_bill'])
plt.show()

# %%
sns.violinplot(x= df['day'], y=df['total_bill'])
sns.swarmplot(x= df['day'], y=df['total_bill'])
plt.show()

# %%
sns.swarmplot(x= df['day'], y=df['total_bill'], hue=df['sex'])
plt.show()

# %%
sns.swarmplot(x= df['sex'], y=df['total_bill'])
plt.show()

# %%
sns.violinplot(x= df['sex'], y=df['total_bill'])
sns.swarmplot(x= df['sex'], y=df['total_bill'])
plt.show()

# %%
sns.swarmplot(x= df['sex'], y=df['total_bill'], hue=df['day'])
plt.show()

# %%
sns.swarmplot(x= df['sex'], y=df['tip'])
plt.show()

# %%
sns.violinplot(x= df['sex'], y=df['tip'])
sns.swarmplot(x= df['sex'], y=df['tip'])
plt.show()

# %%
sns.swarmplot(x= df['sex'], y=df['tip'], hue=df['day'])
plt.show()

# %% [markdown]
# # Heat Map

# %%
flights = sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
dfcorr= df[['total_bill', 'tip', 'size']]

# %%
dfcorr.head()
# Out:
#    total_bill   tip  size
# 0       16.99  1.01     2
# 1       10.34  1.66     3
# 2       21.01  3.50     3
# 3       23.68  3.31     2
# 4       24.59  3.61     4

# %%
dfcorr.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(dfcorr.corr())
plt.show()

# %%
sns.heatmap(dfcorr.corr(), annot=True)
plt.show()

# %% [markdown]
# # Cluster Map

# %%
sns.clustermap(dfcorr.corr())
plt.show()

# %% [markdown]
# # Pivot Table Heat Map

# %%
pvtflight= flights.pivot_table(values="passengers",index="month", columns="year")
# Out:
# C:\Users\OMKAR\AppData\Local\Temp\ipykernel_19540\3635924781.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pvtflight= flights.pivot_table(values="passengers",index="month", columns="year")

# %%
pvtflight
# Out:
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# Aug    148.0  170.0  199.0  242.0  272.0  293.0  347.0  405.0  467.0  505.0
# Sep    136.0  158.0  184.0  209.0  237.0  259.0  312.0  355.0  404.0  404.0
# Oct    119.0  133.0  162.0  191.0  211.0  229.0  274.0  306.0  347.0  359.0
# Nov    104.0  114.0  146.0  172.0  180.0  203.0  237.0  271.0  305.0  310.0
# ...

# %%
import matplotlib.pyplot as plt 
fig = plt.figure(figsize=(20,14))
sns.heatmap(pvtflight)
plt.show()

# %%
sns.lmplot(x= 'total_bill', y='tip', data= df)
plt.show()

# %%
sns.lmplot(x= 'total_bill', y='tip', data= df, hue='sex')
plt.show()

# %%
sns.lmplot(x= 'total_bill', y= 'tip', data= df, hue='sex',markers=['o','v'] )
plt.show()

# %%
sns.lmplot(x= 'total_bill', y='tip', data= df, hue='day')
plt.show()

# %%
sns.lmplot(x= 'total_bill', y= 'tip', hue='day', data=df, markers=['o','v','|','^'])
plt.show()

# %% [markdown]
# ## Task 18: Assignment

# %% [markdown]
# Q1. (Data Loading & Initial Analysis)
#
# Load the Ford Car Dataset using pandas.
#
# Display the first 10 rows and last 5 rows.
#
# Check the shape (number of rows and columns) and data types of all columns.
#
# Write observations about the dataset structure in comments

# %%
import pandas as pd

# %%
# Load the Ford Car Dataset
df = pd.read_csv("ford_car_dataset.csv")

# %%
# Display the first 10 rows
print("First 10 Rows ")
print(df.head(10))

# Display the last 5 rows
print("\nLast 5 Rows ")
print(df.tail(5))
# Out:
# First 10 Rows
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1    Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2    Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3   Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4   Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0
# 5   Fiesta  2015  10500       Manual    35432   Petrol  145  47.9         1.6
# 6     Puma  2019  22500       Manual     2029   Petrol  145  50.4         1.0
# 7   Fiesta  2017   9000       Manual    13054   Petrol  145  54.3         1.2
# 8     Kuga  2019  25500    Automatic     6894   Diesel  145  42.2         2.0
# 9    Focus  2018  10000       Manual    48141   Petrol  145  61.4         1.0
#
# Last 5 Rows
#         model  year  price transmission  mileage fuelType  tax   mpg  \
# ...

# %%
# Check the dataset shape
print(f"\nDataset Shape: {df.shape}")

# Check data types of all columns
print("\nData Types ")
print(df.dtypes)

# Observations about the dataset structure:
# 1. The dataset contains 9 columns representing car specifications (model, year, price, transmission, mileage, fuelType, tax, mpg, engineSize).
# 2. Categorical features include 'model', 'transmission', and 'fuelType' (stored as object data types).
# 3. Numerical features include 'year', 'price', 'mileage', 'tax', 'mpg', and 'engineSize' (stored as int64 or float64).
# 4. 'price' is the continuous numerical dependent variable (target feature) typically used for regression tasks.
# Out:
# Dataset Shape: (17966, 9)
#
# Data Types
# model            object
# year              int64
# price             int64
# transmission     object
# mileage           int64
# fuelType         object
# tax               int64
# mpg             float64
# engineSize      float64
# dtype: object

# %% [markdown]
# Q2. (Missing & Duplicate Values)
#
# Perform a detailed check on the dataset:
#
# Find the total number of missing values in each column.
#
# Identify and remove duplicate rows if any.
#
# Write a summary of your findings and how you handled them in comments.

# %%
# Check for missing values in each column
print("Missing Values Per Column ")
print(df.isnull().sum())

# Check for duplicate rows
duplicate_count = df.duplicated().sum()
print(f"\nNumber of duplicate rows found: {duplicate_count}")

# Remove duplicate rows if any 
if duplicate_count > 0:
    df = df.drop_duplicates()
    print("Duplicate rows have been successfully removed.")
    print(f"New Dataset Shape: {df.shape}")
else:
    print("No duplicate rows found to remove.")

# Summary of findings and handling:
# - Missing Values: The column-wise null count indicates if any data points are absent. Any missing values would typically be handled via deletion or imputation (mean/median for numerical, mode for categorical).
# - Duplicate Rows: Identical rows were checked using df.duplicated(). Leaving duplicate entries can artificially weight certain records, so they are dropped using df.drop_duplicates() to keep the data unique and accurate.
# Out:
# Missing Values Per Column
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64
#
# Number of duplicate rows found: 154
# Duplicate rows have been successfully removed.
# New Dataset Shape: (17812, 9)

# %% [markdown]
# Q3. (Statistical Summary)
#
# Generate the statistical summary of all numeric columns using describe().
#
# Identify minimum, maximum, mean, and median values for key columns like
# price, mileage, and year.

# %%
# Generate statistical summary for all numeric columns
print(" Statistical Summary of Numeric Columns ")
display(df.describe())

# Identify and print specific metrics for key columns
key_columns = ["price", "mileage", "year"]

print("\nKey Column Metrics ")
for col in key_columns:
    if col in df.columns:
        print(f"\nMetrics for '{col}':")
        print(f"  Minimum: {df[col].min()}")
        print(f"  Maximum: {df[col].max()}")
        print(f"  Mean:    {df[col].mean():.2f}")
        print(f"  Median:  {df[col].median()}")
    else:
        print(f"Column '{col}' not found in the DataFrame.")
# Out:
#  Statistical Summary of Numeric Columns
#                year         price        mileage           tax           mpg  \
# count  17812.000000  17812.000000   17812.000000  17812.000000  17812.000000
# mean    2016.862396  12269.556310   23381.146362    113.315012     57.908696
# std        2.052039   4736.285417   19419.011045     62.034603     10.132696
# min     1996.000000    495.000000       1.000000      0.000000     20.800000
# 25%     2016.000000   8999.000000   10000.000000     30.000000     52.300000
# 50%     2017.000000  11288.000000   18277.000000    145.000000     58.900000
# 75%     2018.000000  15295.000000   31098.500000    145.000000     65.700000
# max     2060.000000  54995.000000  177644.000000    580.000000    201.800000
#
#          engineSize
# count  17812.000000
# mean       1.350623
# std        0.432581
# min        0.000000
# 25%        1.000000
# 50%        1.200000
# 75%        1.500000
# max        5.000000
# Key Column Metrics
#
# ...

# %% [markdown]
# Q4. (Histogram of Numeric Features)
#
# Plot histograms for all important numeric columns (price, mileage, year,engineSize, mpg).
#
# Analyze the distribution for each feature and note your findings in comments.

# %%
# Set clean aesthetic style
sns.set_theme(style="whitegrid")


# Define a clean, simple plotting function matching your workflow style
def display_ford_histograms(dataframe):
    target_columns = ["price", "mileage", "year", "engineSize", "mpg"]

    plt.figure(figsize=(15, 10))

    for index, column_name in enumerate(target_columns, 1):
        plt.subplot(2, 3, index)
        sns.histplot(dataframe[column_name], bins=20, kde=True, color="crimson")
        plt.title(f"Distribution of {column_name}")
        plt.xlabel(column_name)
        plt.ylabel("Frequency")

    plt.tight_layout()
    plt.show()

# Execute the function to draw the graphs
display_ford_histograms(df)

# Distribution Insights & Findings:
# Price: Most cars are under £20,000, with a few expensive models.
# Mileage: Most cars have low mileage (under 40,000 miles).
# Year: Most cars are modern and recently manufactured (post-2016).
# EngineSize: Most cars have small, efficient engines (1.0L to 2.0L).
# Mpg: Most cars get excellent fuel economy, peaking around 50–60 mpg.

# %% [markdown]
# Q5. (Count Plots of Categorical Features)
#
# Create count plots for all categorical columns (fuelType, transmission, model, etc.)using seaborn.
#
# Analyze which categories are most common.
#
# Write insights about market trends based on these plots in comments.

# %%
# Set clean aesthetic style
sns.set_theme(style="whitegrid")

# Count Plots (Categorical Features)
# Visualizing the frequency distribution of categorical columns
plt.figure(figsize=(15, 12))

# Count plot for transmission
plt.subplot(2, 2, 1)
sns.countplot(
    data=df,
    x="transmission",
    palette="viridis",
    order=df["transmission"].value_counts().index,
)
plt.title("Frequency of Transmission Types")
plt.xlabel("Transmission")
plt.ylabel("Count")

# Count plot for fuelType
plt.subplot(2, 2, 2)
sns.countplot(
    data=df,
    x="fuelType",
    palette="magma",
    order=df["fuelType"].value_counts().index,
)
plt.title("Frequency of Fuel Types")
plt.xlabel("Fuel Type")
plt.ylabel("Count")

# Count plot for car model (Top 10 most common models for readability)
plt.subplot(2, 2, (3, 4))
sns.countplot(
    data=df,
    y="model",
    palette="cubehelix",
    order=df["model"].value_counts().iloc[:10].index,
)
plt.title("Top 10 Most Common Ford Models")
plt.xlabel("Count")
plt.ylabel("Model")

plt.tight_layout()
plt.show()

# Market Trend Insights:
# - Transmission: Manual cars dominate the market segment, followed by Automatic and Semi-Auto options.
# - Fuel Type: Petrol is the most popular choice, closely followed by Diesel, while Eco-friendly/Hybrids form a very small niche.
# - Model: High-volume, budget-friendly models like the Fiesta and Focus heavily drive Ford's sales volume.
# Out:
# C:\Users\OMKAR\AppData\Local\Temp\ipykernel_15372\3264806676.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(
# C:\Users\OMKAR\AppData\Local\Temp\ipykernel_15372\3264806676.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(
# C:\Users\OMKAR\AppData\Local\Temp\ipykernel_15372\3264806676.py:34: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %% [markdown]
# Q6. (Correlation Heatmap)
#
# Create a heatmap of the correlation matrix for numeric features.
#
# Use seaborn with proper annotations.
#
# Identify which features are highly correlated with the target variable (price).
#
# Write your observations in comment.

# %%
import numpy as np

# Set clean aesthetic style
sns.set_theme(style="whitegrid")

# Heatmap (Correlation Matrix)
plt.figure(figsize=(10, 6))
numeric_df = df.select_dtypes(include=[np.number])
sns.heatmap(
    numeric_df.corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5
)
plt.title("Correlation Matrix of Numeric Features")
plt.show()

# Correlation Insights & Observations:
# Year and Price: Newer cars cost significantly more.
# Mileage and Price: Higher mileage heavily reduces a car's price.
# Engine Size and Price: Larger engines drive up the cost.
# Mpg and Price: More fuel-efficient cars tend to be cheaper.

# %% [markdown]
# Q7. (Feature Identification)
#
# Clearly identify and list:
#
# Independent Features (Input Features)
#
# Dependent Feature (Output/Target Feature)
#
# Justify your choice with reasoning.

# %%
# Separate independent (input) and dependent (target) features
X = df.drop(columns=["price"])  # Independent Features
y = df["price"]  # Dependent Feature

print("Independent Features (X):", X.columns.tolist())
print("Dependent Feature (y):", y.name)
# Out:
# Independent Features (X): ['model', 'year', 'transmission', 'mileage', 'fuelType', 'tax', 'mpg', 'engineSize']
# Dependent Feature (y): price

# %% [markdown]
# Q8. (Encoding Categorical Variables)
#
# Convert all categorical columns into numeric form using appropriate encoding techniques:
#
# Use One Hot Encoding.
#
# Show before and after transformation for at least 2 columns

# %%
# Show the columns before transformation
print("Before One-Hot Encoding (Sample Columns) ")
print(df[["transmission", "fuelType"]].head())

# Perform One-Hot Encoding on all categorical columns
categorical_cols = ["model", "transmission", "fuelType"]
df_encoded = pd.get_dummies(df, columns=categorical_cols)

# Show the columns after transformation to verify encoding
print("\nAfter One-Hot Encoding (Sample Columns) ")
# Filtering columns derived from transmission and fuelType
after_columns = df_encoded.filter(like="transmission").join(
    df_encoded.filter(like="fuelType")
)
print(after_columns.head())

# Print final shape of the new encoded dataframe
print(f"\nNew DataFrame Shape: {df_encoded.shape}")
# Out:
# Before One-Hot Encoding (Sample Columns)
#   transmission fuelType
# 0    Automatic   Petrol
# 1       Manual   Petrol
# 2       Manual   Petrol
# 3       Manual   Petrol
# 4    Automatic   Petrol
#
# After One-Hot Encoding (Sample Columns)
#    transmission_Automatic  transmission_Manual  transmission_Semi-Auto  \
# 0                    True                False                   False
# 1                   False                 True                   False
# 2                   False                 True                   False
# 3                   False                 True                   False
# 4                    True                False                   False
#
#    fuelType_Diesel  fuelType_Electric  fuelType_Hybrid  fuelType_Other  \
# 0            False              False            False           False
# 1            False              False            False           False
# 2            False              False            False           False
# ...

# %% [markdown]
# Q9. (Feature Scaling)
#
# Apply Standard Scaling (using StandardScaler from sklearn) on the numeric independent features.
#
# Show the first 5 rows of scaled data.

# %%
from sklearn.preprocessing import StandardScaler

# Identify numeric independent features (excluding the target 'price')
numeric_features = ["year", "mileage", "tax", "mpg", "engineSize"]

# Initialize the StandardScaler
scaler = StandardScaler()

# Create a copy of the encoded dataframe to preserve structure
df_scaled = df_encoded.copy()

# Apply scaling to the numeric independent columns
df_scaled[numeric_features] = scaler.fit_transform(
    df_encoded[numeric_features]
)

# Display the first 5 rows of the scaled numeric features
print("First 5 Rows of Scaled Numeric Features ")
print(df_scaled[numeric_features].head())
# Out:
# First 5 Rows of Scaled Numeric Features
#        year   mileage       tax       mpg  engineSize
# 0  0.067059 -0.382994  0.591380 -0.020597   -0.810561
# 1  0.554393 -0.736317  0.591380 -0.020597   -0.810561
# 2  0.067059 -0.562616  0.591380 -0.020597   -0.810561
# 3  1.041726 -0.665405  0.510777 -1.737858    0.345325
# 4  1.041726 -1.127749  0.510777 -0.908836   -0.810561

# %% [markdown]
# Q10. (Mini Project - Complete Preprocessing Pipeline)
#
# Create a complete preprocessing pipeline for the Ford Car Dataset:
# 1. Load and clean the data (handle missing & duplicate values).
# 2. Perform EDA (histograms + count plots + heatmap).
# 3. Identify input and output features.
# 4. Encode categorical variables.
# 5. Scale the numeric features.

# %% [markdown]
# 1. LOAD AND CLEAN THE DATA

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Load the dataset
df = pd.read_csv("ford_car_dataset.csv")

# Handle duplicate values
duplicate_count = df.duplicated().sum()
if duplicate_count > 0:
    df = df.drop_duplicates()

# Confirm structural status
print(f"Data successfully cleaned. Current dataset shape: {df.shape}")
print("Missing values per column:\n", df.isnull().sum())
# Out:
# Data successfully cleaned. Current dataset shape: (17812, 9)
# Missing values per column:
#  model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %% [markdown]
# 2. PERFORM EXPLORATORY DATA ANALYSIS (EDA)

# %%
# Set styling aesthetics
import seaborn as sns

sns.set_theme(style="whitegrid")
plt.figure(figsize=(16, 12))

# Histogram - Target Feature Distribution
plt.subplot(2, 3, 1)
sns.histplot(df["price"], kde=True, color="crimson")
plt.title("Distribution of Price")

# Histogram - Mileage Distribution
plt.subplot(2, 3, 2)
sns.histplot(df["mileage"], kde=True, color="teal")
plt.title("Distribution of Mileage")

# Count Plot - Transmission Types
plt.subplot(2, 3, 3)
sns.countplot(
    data=df, x="transmission", order=df["transmission"].value_counts().index
)
plt.title("Transmission Type Frequency")

# Count Plot - Fuel Types
plt.subplot(2, 3, 4)
sns.countplot(data=df, x="fuelType", order=df["fuelType"].value_counts().index)
plt.title("Fuel Type Frequency")

# Heatmap - Correlation Matrix
plt.subplot(2, 3, (5, 6))
numeric_df = df.select_dtypes(include=[np.number])
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")

plt.tight_layout()
plt.show()

# %% [markdown]
# 3. IDENTIFY INPUT AND OUTPUT FEATURES

# %%
# Split data into target vector (y) and input feature matrix (X)
X = df.drop(columns=["price"])
y = df["price"]

# %% [markdown]
# 4. ENCODE CATEGORICAL VARIABLES

# %%
# Transform qualitative features via One-Hot Encoding
categorical_cols = ["model", "transmission", "fuelType"]
X_encoded = pd.get_dummies(X, columns=categorical_cols)

# %% [markdown]
# 5. SCALE THE NUMERIC FEATURES

# %%
# Initialize scaling metrics for independent continuous variables
numeric_features = ["year", "mileage", "tax", "mpg", "engineSize"]
scaler = StandardScaler()

# Transform features using z-score normalization
X_scaled = X_encoded.copy()
X_scaled[numeric_features] = scaler.fit_transform(X_encoded[numeric_features])

# %%
# Print final verification
print("\nPipeline Completed ")
print(f"Final Preprocessed Feature Matrix Shape: {X_scaled.shape}")
print("\nFirst 5 Rows of Fully Processed Inputs:")
display(X_scaled.head())
# Out:
# Pipeline Completed
# Final Preprocessed Feature Matrix Shape: (17812, 37)
#
# First 5 Rows of Fully Processed Inputs:
#        year   mileage       tax       mpg  engineSize  model_ B-MAX  \
# 0  0.067059 -0.382994  0.591380 -0.020597   -0.810561         False
# 1  0.554393 -0.736317  0.591380 -0.020597   -0.810561         False
# 2  0.067059 -0.562616  0.591380 -0.020597   -0.810561         False
# 3  1.041726 -0.665405  0.510777 -1.737858    0.345325         False
# 4  1.041726 -1.127749  0.510777 -0.908836   -0.810561         False
#
#    model_ C-MAX  model_ EcoSport  model_ Edge  model_ Escort  ...  \
# 0         False            False        False          False  ...
# 1         False            False        False          False  ...
# 2         False            False        False          False  ...
# 3         False            False        False          False  ...
# 4         False            False        False          False  ...
#
# ...

# %% [markdown]
# Optional Task
#
# Apply all the things your have learned till now on
#
# Insurance Dataset
#
# Dataset you use for Session 16’s Optional Task
#
# Another new dataset (Use Github or Kaggle to get datasets)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# 1. LOAD AND CLEAN THE DATA

# %%
# Load the dataset
df = pd.read_csv("insurance_2.csv")

# Drop rows where critical categorical info is completely missing
df = df.dropna(subset=["sex", "smoker", "region"])

# Convert numeric columns safely now that corrupted rows are gone
df["age"] = df["age"].astype(float).astype(int)  # Handles float-like strings safely
df["bmi"] = df["bmi"].astype(float)
df["children"] = df["children"].astype(int)

# Handle duplicate values
duplicate_count = df.duplicated().sum()
if duplicate_count > 0:
    df = df.drop_duplicates()

print(f"Data successfully cleaned. Current shape: {df.shape}")
# Out:
# Data successfully cleaned. Current shape: (1335, 6)

# %% [markdown]
# 2. EXPLORATORY DATA ANALYSIS (EDA)

# %%
sns.set_theme(style="whitegrid")
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Histogram - Age Distribution
sns.histplot(df["age"], kde=True, color="darkcyan", ax=axes[0, 0])
axes[0, 0].set_title("Distribution of Age")

# Histogram - BMI Distribution
sns.histplot(df["bmi"], kde=True, color="purple", ax=axes[0, 1])
axes[0, 1].set_title("Distribution of BMI")

#  Count Plot - Smoker Distribution
sns.countplot(data=df, x="smoker", palette="Set2", ax=axes[1, 0])
axes[1, 0].set_title("Count of Smokers vs Non-Smokers")

#  Heatmap - Correlation Matrix of existing numeric features
numeric_df = df.select_dtypes(include=[np.number])
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm", fmt=".2f", ax=axes[1, 1])
axes[1, 1].set_title("Correlation Matrix")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\OMKAR\AppData\Local\Temp\ipykernel_28772\2105730954.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="smoker", palette="Set2", ax=axes[1, 0])

# %% [markdown]
# 3. SPLIT & FEATURE PREPROCESSING PIPELINE

# %%
# Since there is no target column, X is just your entire dataframe
X = df.copy()

# Encode all categorical features using One-Hot Encoding
categorical_cols = ["sex", "smoker", "region"]
X_encoded = pd.get_dummies(X, columns=categorical_cols)

# Scale all numeric features
numeric_features = ["age", "bmi", "children"]
scaler = StandardScaler()

X_scaled = X_encoded.copy()
X_scaled[numeric_features] = scaler.fit_transform(X_encoded[numeric_features])

print("Data Pipeline Completed ")
print(f"Final Preprocessed Feature Matrix Shape: {X_scaled.shape}")
# Out:
# Data Pipeline Completed
# Final Preprocessed Feature Matrix Shape: (1335, 11)
